# %%
from fastapi import FastAPI
import joblib
import numpy as np
app=FastAPI()
model=joblib.load('XGB_Churn_model.pkl')
print('model-loaded')
@app.get('/')
def home()
# Out:
# model-loaded

# %%
! pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 442.2 kB/s eta 0:03:49
#    ---------------------------------------- 0.5/101.7 MB 442.2 kB/s eta 0:03:49
#    ---------------------------------------- 0.5/101.7 MB 442.2 kB/s eta 0:03:49
#    ---------------------------------------- 0.8/101.7 MB 425.2 kB/s eta 0:03:58
# ...

# %%
import xgboost
